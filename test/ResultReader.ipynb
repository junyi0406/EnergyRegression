# %%
import pickle as pk
folder = "/home/JYChen/EnergyRegression/samples/results/Run3_DoubleElectron/"
filename = "DoubleElectron_ECALIdealIC_PostEE_124X_30032023_eb_applied.pk" # nevt = 34919170
with open(f"{folder}{filename}", "rb") as file:
    df = pk.load(file=file)

# %%
# Out:
#       sc_rawEnergy  sc_etaWidth  sc_phiWidth  sc_seedClusEnergy/sc_rawEnergy  \
# 0       256.804749     0.005595     0.021323                        0.950370
# 1       282.092865     0.007216     0.017977                        0.914286
# 2        37.291946     0.003056     0.039026                        0.488712
# 3        41.542633     0.006690     0.039849                        0.986926
# 4        87.159348     0.005760     0.018623                        0.978386
# ...            ...          ...          ...                             ...
# 4781    262.421204     0.006948     0.021023                        0.998445
# 4782    455.732513     0.009326     0.014704                        0.995448
# 4783    454.605103     0.009044     0.021166                        0.983040
# 4784    437.723511     0.008519     0.010440                        1.000000
# 4785    447.103363     0.006894     0.019953                        0.997698
#
# ...

# %%
# df.Tar.hist(bins=30, range=(0.5, 1.5), histtype="step")
( df["mean"]/df["Tar"] ).hist(bins=30, range=(0, 200), histtype="step")
# Out:
# <Axes: >
